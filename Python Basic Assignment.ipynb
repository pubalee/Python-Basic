# %% [markdown]
# Python

# %% [markdown]
# 1. What is Python, and why is it popular ?
# Ans: Python is a versatile, high-level, interpreted programming language known for its readability and ease of use.
# It is popular among industries for following reason:
# -Ease of Learning
# -Versatality
# -Lots of Libraries
# -Huge active community
#
# 2. What is an interpreter in Python
# Ans: In Python, an interpreter is a program that reads and executes Python code line by line, without requiring it to be compiled into machine code first. It translates the code into machine-readable instructions and then executes them directly. E.g: VS code, Pycham, Google colab etc..
#
# 3. What are pre-defined keywords in Python
# Ans: Following are the pre-defined keywords in Python:
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not
#
# 4. Can keywords be used as variable names
# Ans: No, Variables canot be keywords
#
# 5. What is mutability in Python
# Ans: In Python, mutability refers to an object's ability to be modified after it is created. Mutable objects can have their values or contents changed without creating a new object, while immutable objects cannot.
#
# 6. Why are lists mutable, but tuples are immutable
# Ans:Lists are mutable but tuples are immutable because once a tuple is created, its contents cannot be changed. In contrast, lists are mutable, meaning that their contents can be modified after they are created.
#
# 7. What is the difference between “==” and “is” operators in Python
# Ans: Difference between "==" and "is" operators in Pyhthon are :
#
#       "=="                                         "is"
# Checks for value equality                   Checks for object identity
# Compares the content or data of objects     Compares memory addresses of objects
# True if values are equal                    True if both variables refer to the same object
#
#
# 8. What are logical operators in Python
# Ans: THere are three logical operators in Python,namely : 'and' , 'or' and 'not'
#
# 9. What is type casting in Python
# Ans: Type casting, also known as type conversion, is the process of changing a variable's data type from one to another.
# e.g:
# a="3.5"
# type(a)
# str
# type(float(a))
# float
#
# 10. What is the difference between implicit and explicit type casting
# Ans: Implicit type casting, also known as widening or upcasting, is automatically performed by the compiler when a smaller data type is converted to a larger one. Explicit type casting, also known as narrowing or downcasting, requires the programmer to explicitly convert a larger data type to a smaller one, often involving the risk of data loss.
#
# 11. What is the purpose of conditional statements in Python
# Ans: Conditional statements in Python are used to control the flow of execution of a program based on whether a specific condition is true or false.
#
# 12. How does the elif statement work
# Ans: 'Elif' stands for 'else if' and is used in Python programming to test multiple conditions. It is written following an if statement in Python to check an alternative condition if the first condition is false. The code block under the elif statement will be executed only if its condition is true.
#
# 13. What is the difference between for and while loops
# Ans:The main difference between for and while loops is that for loops iterate over a sequence (like a list or array), while while loops continue executing as long as a condition is true. In essence, for loops are used when you know the number of iterations beforehand, and while loops are used when the number of iterations is determined by a dynamic condition.
#
# 14. Describe a scenario where a while loop is more suitable than a for loop
# Ans:For loops are best used when you know the number of iterations ahead of time, whereas a while loop is best used when you don't know the number of iterations in advance.
# E.g: #For iteration and counting I prefer using for loops,
# for (int i=0; i<10; ++i) {
#   /* body */
# }
#
# # On the other hand, reading from files I usually prefer while lops:
# while (!eof(file_handle)) {
#   /* read from file */
# }

# %%
##Practical Questions

# 1. Write a Python program to print "Hello, World!"?

#Ans:
print("Hello, World!")

#2. Write a Python program that displays your name and age?
#Ans:
name = "Pubalee"
age = 31
print("Name:", name)
print("Age:", age)

#3. Write code to print all the pre-defined keywords in Python using the keyword library?
#Ans:
help('keywords')

import keyword

print(keyword.kwlist)


#4.Write a program that checks if a given word is a Python keyword?
#Ans:
import keyword



#5. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.
#Ans:
my_list = [1, 2, 3]
print("Original list:", my_list)

my_list[1] = 4
print("Modified list:", my_list)


#6. Write a function to demonstrate the behavior of mutable and immutable arguments?
#Ans:
immutable_value = 10
mutable_value = [1, 2, 3]

demonstrate_mutability(immutable_value, mutable_value)

print("Outside function - immutable_value:", immutable_value, "id:", id(immutable_value))
print("Outside function - mutable_value:", mutable_value, "id:", id(mutable_value))


#7. Write a program that performs basic arithmetic operations on two user-input numbers.
#Ans:

num1 = int(input('Enter First number: '))
num2 = int(input('Enter Second number '))
add = num1 + num2

print('Sum of ',num1 ,'and' ,num2 ,'is :',add)

#8. Write a program to demonstrate the use of logical operators.
#Ans:
# Logical AND
x = 5
print(x > 0 and x < 10)  # Output: True (Both conditions are true)
print(x > 0 and x > 10)  # Output: False (Second condition is false)

# Logical OR
y = 15
print(y > 0 or y < 10)  # Output: True (First condition is true)
print(y < 0 or y < 10)  # Output: False (Both conditions are false)

# Logical NOT
z = True
print(not z)  # Output: False (Negates the boolean value)
print(not (y > 10))  # Output: False (Negates the result of the condition)


#9. Write a Python program to convert user input from string to integer, float, and boolean types.
#Ans:

name = int(name)
type(name)
a = "3.5"
type(float(a))
bool(0)

#10. Write code to demonstrate type casting with list elements.
#Ans:
name = int(name)
type(name)
a = "3.5"
type(float(a))
bool(0)


#11. Write a program that checks if a number is positive, negative, or zero.
#Ans:

number = int(input("Enter a number: "))
result = check_number(number)
print(f"The number {number} is {result}.")


#12. Write a for loop to print numbers from 1 to 10.
#Ans:
for i in range(1, 11):
    print(i)


#13. Write a Python program to find the sum of all even numbers between 1 and 50.
#Ans:
sum_of_evens = 0
for number in range(2, 51, 2):
    sum_of_evens += number
print(sum_of_evens)

#14. Write a program to reverse a string using a while loop.
#Ans:

def reverse_string(s):
    reversed_s = ""
    length = len(s) - 1
    while length >= 0:
        reversed_s += s[length]
        length -= 1
    return reversed_s

input_string = "Hello, World!"
reversed_string = reverse_string(input_string)
print(f"Original string: {input_string}")
print(f"Reversed string: {reversed_string}")

#15. Write a Python program to calculate the factorial of a number provided by the user using a while loop.
#Ans:

ef factorial_while_loop(n):
    if n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0:
        return 1
    else:
        factorial = 1
        while n > 1:
            factorial *= n
            n -= 1
        return factorial

# Get input from the user
num = int(input("Enter a number: "))

# Calculate and print the factorial
result = factorial_while_loop(num)
print(f"The factorial of {num} is {result}")
# Out:
#   File "<ipython-input-2-1318970891>", line 29
#     return keyword.iskeyword(word)
#     ^
# IndentationError: expected an indented block after function definition on line 28
